# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import json
import os
from openai import OpenAI
from getpass import getpass
from dotenv import load_dotenv  

load_dotenv(".env")  # or wherever your API key is
api_key = os.getenv("OPENAI_API_KEY")
client = OpenAI(api_key=api_key)

# %% [markdown]
# Step 1: Fetch raw HTML

# %%
import requests
import pdfplumber
from io import BytesIO
from bs4 import BeautifulSoup

# PDF URLs from MUIS
pdf_urls = [
    "https://file.go.gov.sg/hcc-eec1.pdf",
    "https://file.go.gov.sg/hcc-pwp.pdf",
    "https://file.go.gov.sg/hcc-pa.pdf",
    "https://file.go.gov.sg/hec-en.pdf",
    "https://file.go.gov.sg/hcc-sf.pdf",
    "https://file.go.gov.sg/hcc-fpa.pdf"
]

# HTML URLs
html_urls = [
    # licence for import, export and transhipment
    "https://www.sfa.gov.sg/food-import-export/commercial-imports/what-you-need-to-know-for-import-of-animal-feed",
    "https://www.sfa.gov.sg/commercial-exports/what-you-need-to-know-for-export-tranship-of-animal-feed",
    "https://licensing.gobusiness.gov.sg/licence-directory/sfa/licence-for-importexporttranshipment-of-meat-and-fish-products",
    "https://licensing.gobusiness.gov.sg/licence-directory/sfa/licence-for-importtranshipment-of-fresh-fruits-and-vegetables",
    "https://licensing.gobusiness.gov.sg/licence-directory/sfa/licence-to-import-poultry",
    "https://licensing.gobusiness.gov.sg/licence-directory/sfa/licence-to-import-sheep--goats",
    "https://licensing.gobusiness.gov.sg/licence-directory/sfa/licence-to-import-table-eggs",
    "https://licensing.gobusiness.gov.sg/licence-directory/sfa/licence-to-importexporttranship-food-animals-birds-eggs-and-biologics",
    "https://licensing.gobusiness.gov.sg/licence-directory/sfa/registration-to-import-feed-for-food-producing-animals",
    "https://licensing.gobusiness.gov.sg/licence-directory/sfa/registration-to-import-feed-for-food-producing-animals",
    "https://licensing.gobusiness.gov.sg/licence-directory/sfa/registration-to-import-processed-food-products-and-food-appliances"
    "https://licensing.gobusiness.gov.sg/licence-directory/sfa/registration-to-import-live-frogs-for-human-consumption",
    "https://licensing.gobusiness.gov.sg/licence-directory/sfa/rice-licence",
    "https://licensing.gobusiness.gov.sg/e-adviser/imports-and-exports",
    # licence for food retail
    "https://www.sfa.gov.sg/food-retail/licence-permit/requirements-for-licence-permit-for-food-retail",
    "https://www.sfa.gov.sg/food-retail/businesses-that-currently-do-not-need-licence-permit/online-food-businesses/types-of-online-food-businesses",
    "https://www.sfa.gov.sg/food-retail/businesses-that-currently-do-not-need-licence-permit/home-based-food-businesses/about-hdb-ura-home-based-business-scheme",
    "https://www.sfa.gov.sg/food-retail/businesses-that-currently-do-not-need-licence-permit/food-delivery-businesses/requirements-for-food-delivery-businesses",
    "https://www.sfa.gov.sg/food-retail/businesses-that-currently-do-not-need-licence-permit/group-buy-activities/guidelines-for-group-buy-organisers",
    "https://licensing.gobusiness.gov.sg/licence-directory/sfa/food-shop-licence",
    "https://licensing.gobusiness.gov.sg/licence-directory/sfa/food-stall-licence",
    "https://licensing.gobusiness.gov.sg/licence-directory/sfa/supermarket-licence",
    "https://licensing.gobusiness.gov.sg/licence-directory/sfa/permit-for-temporary-fair",
    "https://licensing.gobusiness.gov.sg/licence-directory/sfa/temporary-fair-stall-licence",
    # licence for food non-retail
    "https://www.sfa.gov.sg/food-manufacturing-storage/licence-registration/businesses-that-need-licence-registration-for-food-manufacturing-storage",
    "https://licensing.gobusiness.gov.sg/licence-directory/sfa/licence-to-operate-a-coldstore",
    "https://licensing.gobusiness.gov.sg/licence-directory/sfa/licence-to-operate-a-food-processing-establishment",
    "https://licensing.gobusiness.gov.sg/licence-directory/sfa/licence-to-operate-slaughter-house",
    "https://licensing.gobusiness.gov.sg/licence-directory/sfa/registration-of-food-storage-warehouses",
    "https://www.sfa.gov.sg/food-manufacturing-storage/licence-registration/application-process-fees-for-licence-to-manufacture-and-process-animal-feed",
    "https://licensing.gobusiness.gov.sg/licence-directory/sfa/licence-to-manufacture-animal-feed-and-process-of-animal-feed-for-food-producing-animals",
    # licence for farming
    "https://www.sfa.gov.sg/farming/licence-registration/businesses-that-need-licence-registration-for-farming",
    "https://www.sfa.gov.sg/farming/pesticides/requirements-for-pesticide-usage-in-farms",
    "https://www.sfa.gov.sg/wholesale-markets-fishery-ports/licence-registration/businesses-that-need-licence-registration-for-fishing-vessel-gear-personnel",
    # licence for export Health, Veterinary & Food Safety
    "https://licensing.gobusiness.gov.sg/licence-directory/sfa/health-certificate-for-export-of-live-foodfish-for-breeding",
    "https://licensing.gobusiness.gov.sg/licence-directory/sfa/export-health-certificate",
    "https://licensing.gobusiness.gov.sg/licence-directory/sfa/free-sale-certificate-food",
    "https://licensing.gobusiness.gov.sg/licence-directory/sfa/free-sale-certificate-animal-feed-for-food-producing-animals",
    "https://licensing.gobusiness.gov.sg/licence-directory/sfa/veterinary-certificate-for-food-producing-animals",
    "https://licensing.gobusiness.gov.sg/licence-directory/sfa/submission-form-for-food-safety-management-system",
    # others
    "https://www.sfa.gov.sg/regulatory-standards-frameworks-guidelines/food-safety-management/understanding-food-safety-management-system-fsms",
    "https://www.sfa.gov.sg/faqs#food-retail-general",
    "https://www.police.gov.sg/E-Services/Apply-for-Liquor-Licence",
    "https://onemotoring.lta.gov.sg/content/onemotoring/home/buying/vehicle-types-and-registrations/commercial-vehicle/goods-vehicle-and-engineering-plant.html",
    "https://www.nea.gov.sg/our-services/hawker-management/becoming-a-hawker",
    "https://www.muis.gov.sg/halal/for-business/scheme-types---eligibility-criteria/",
    "https://www.hsa.gov.sg/tobacco-regulation/licences/retail/apply"
]

# Step 1: Extract PDF texts
pdf_pages = []

for url in pdf_urls:
    try:
        response = requests.get(url)
        response.raise_for_status()
        pdf_file = BytesIO(response.content)

        with pdfplumber.open(pdf_file) as pdf:
            text = ""
            for page in pdf.pages:
                page_text = page.extract_text()
                if page_text:
                    text += page_text + "\n"

        pdf_pages.append({"url": url, "text": text})
        print(f"Processed PDF: {url}")

    except Exception as e:
        print(f"Failed to process PDF {url}: {e}")

# Step 2: Extract HTML texts (with headers to avoid 403)
html_pages = []

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
    "Accept-Language": "en-US,en;q=0.9",
}

for url in html_urls:
    try:
        resp = requests.get(url, headers=headers, timeout=60)
        resp.raise_for_status()
        soup = BeautifulSoup(resp.text, "html.parser")

        # Remove scripts, styles, noscript
        for tag in soup(["script", "style", "noscript"]):
            tag.decompose()

        text_content = soup.get_text(separator="\n", strip=True)
        html_pages.append({"url": url, "text": text_content})
        print(f"Processed HTML: {url}")

    except Exception as e:
        print(f"Failed to process HTML {url}: {e}")

# Step 3: Combine PDF and HTML pages into a single object
all_pages = pdf_pages + html_pages

# Example: preview first entry
print(all_pages[0]["url"])
print(all_pages[0]["text"][:500])  # first 500 characters
# Out:
# Processed PDF: https://file.go.gov.sg/hcc-eec1.pdf
# Processed PDF: https://file.go.gov.sg/hcc-pwp.pdf
# Processed PDF: https://file.go.gov.sg/hcc-pa.pdf
# Processed PDF: https://file.go.gov.sg/hec-en.pdf
# Processed PDF: https://file.go.gov.sg/hcc-sf.pdf
# Processed PDF: https://file.go.gov.sg/hcc-fpa.pdf
# Processed HTML: https://www.sfa.gov.sg/food-import-export/commercial-imports/what-you-need-to-know-for-import-of-animal-feed
# Processed HTML: https://www.sfa.gov.sg/commercial-exports/what-you-need-to-know-for-export-tranship-of-animal-feed
# Processed HTML: https://www.gobusiness.gov.sg/browse-all-licences/singapore-food-agency-(sfa)/licence-for-import-export-transhipment-of-meat-and-fish-products
# Processed HTML: https://www.gobusiness.gov.sg/browse-all-licences/singapore-food-agency-(sfa)/licence-for-import-transhipment-of-fresh-fruits-and-vegetables
# Processed HTML: https://www.gobusiness.gov.sg/browse-all-licences/singapore-food-agency-(sfa)/licence-to-import-poultry
# Processed HTML: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/Licence-to-Import-Sheep-&-Goats
# Processed HTML: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/Licence-to-Import-Table-Eggs
# Processed HTML: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/licence-to-import-export-tranship-food-animals--birds--eggs-and-biologics
# Processed HTML: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/Registration-to-Import-Animal-Feed
# Processed HTML: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/Registration-to-Import-Feed-for-Food-Producing-Animals
# Processed HTML: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/Registration-to-Import-Processed-Food-Products-and-Food-Appliances
# Processed HTML: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/Registration-to-Import-Live-Frogs-for-Human-Consumption
# Processed HTML: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/Rice-Licence
# Processed HTML: https://www.sfa.gov.sg/food-retail/licence-permit/requirements-for-licence-permit-for-food-retail
# Processed HTML: https://www.sfa.gov.sg/food-retail/businesses-that-currently-do-not-need-licence-permit/online-food-businesses/types-of-online-food-businesses
# Processed HTML: https://www.sfa.gov.sg/food-retail/businesses-that-currently-do-not-need-licence-permit/home-based-food-businesses/about-hdb-ura-home-based-business-scheme
# Processed HTML: https://www.sfa.gov.sg/food-retail/businesses-that-currently-do-not-need-licence-permit/food-delivery-businesses/requirements-for-food-delivery-businesses
# Processed HTML: https://www.sfa.gov.sg/food-retail/businesses-that-currently-do-not-need-licence-permit/group-buy-activities/guidelines-for-group-buy-organisers
# Processed HTML: https://www.gobusiness.gov.sg/browse-all-licences/singapore-food-agency-(sfa)/food-shop-licence
# Processed HTML: https://www.gobusiness.gov.sg/browse-all-licences/singapore-food-agency-(sfa)/food-stall-licence
# Processed HTML: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/Supermarket-Licence
# Processed HTML: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/Permit-for-Temporary-Fair
# Processed HTML: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/Temporary-Fair-Stall-Licence
# Processed HTML: https://www.sfa.gov.sg/food-manufacturing-storage/licence-registration/businesses-that-need-licence-registration-for-food-manufacturing-storage
# Processed HTML: https://www.sfa.gov.sg/food-manufacturing-storage/licence-registration/application-process-fees-for-licence-to-manufacture-and-process-animal-feed
# Processed HTML: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/Licence-to-Manufacture-Animal-Feed-and-Process-of-Animal-Feed-for-Food-Producing-Animals
# Processed HTML: https://www.sfa.gov.sg/farming/licence-registration/businesses-that-need-licence-registration-for-farming
# Processed HTML: https://www.sfa.gov.sg/farming/pesticides/requirements-for-pesticide-usage-in-farms
# Processed HTML: https://www.sfa.gov.sg/wholesale-markets-fishery-ports/licence-registration/businesses-that-need-licence-registration-for-fishing-vessel-gear-personnel
# Processed HTML: https://www.gobusiness.gov.sg/browse-all-licences/singapore-food-agency-(sfa)/health-certificate-for-export-of-live-foodfish-for-breeding
# Processed HTML: https://www.gobusiness.gov.sg/browse-all-licences/singapore-food-agency-(sfa)/export-health-certificate
# Processed HTML: https://www.gobusiness.gov.sg/browse-all-licences/singapore-food-agency-(sfa)/free-sale-certificate-(food)
# Processed HTML: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/Free-Sale-Certificate-(Animal-Feed)-for-Food-Producing-Animals
# Processed HTML: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/Veterinary-Certificate-for-Food-Producing-Animals
# Processed HTML: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/Submission-Form-for-Food-Safety-Management-System
# Processed HTML: https://www.sfa.gov.sg/regulatory-standards-frameworks-guidelines/food-safety-management/understanding-food-safety-management-system-fsms
# Processed HTML: https://www.sfa.gov.sg/faqs#food-retail-general
# Processed HTML: https://www.police.gov.sg/E-Services/Apply-for-Liquor-Licence
# Processed HTML: https://onemotoring.lta.gov.sg/content/onemotoring/home/buying/vehicle-types-and-registrations/commercial-vehicle/goods-vehicle-and-engineering-plant.html
# Processed HTML: https://www.nea.gov.sg/our-services/hawker-management/becoming-a-hawker
# Processed HTML: https://www.muis.gov.sg/halal/for-business/scheme-types---eligibility-criteria/
# Processed HTML: https://www.hsa.gov.sg/tobacco-regulation/licences/retail/apply
# https://file.go.gov.sg/hcc-eec1.pdf
# MUIS Halal Certification Conditions HCC EEC1 (Version 4.0)
# Eating Establishment Scheme (Category 1)
# Majlis Ugama Islam Singapura
# Halal Certification Conditions
# This document is provided for the application for Halal
# Certification by the Majlis Ugama Islam Singapura
# with effect from 1 October 2025
# EATING ESTABLISHMENT SCHEME
# (Category 1)
# Copyright © Majlis Ugama Islam Singapura, 2025
# All rights reserved. No part of this document may be reproduced, transmitted in any form or by any means
# electroni
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Step 2: Use LLM to parse structured content

# %%
def parse_text_with_llm(text, url):
    prompt = f"""
You are a careful information extraction assistant.

Return ONLY a valid JSON array of objects, no markdown, no comments, no explanations. 
Each object must have:
- "title": short descriptive title (from the text if possible)
- "subsection": subsection heading if available, else null
- "licence": 
    - one exact matching licence name (from the official list below), OR
    - "No licence required" if the text states that no licence is needed
- "description": relevant text excerpt including URLs if found, including which food, service or practices are applicable to the licence e.g. "Exporting Singapore origin, finished product, in respect of which a Halal 
certificate has been issued by MUIS"
- "reason_for_licence": short explanation (e.g., “Home-based food businesses do not require an SFA licence to operate. ”)
- "requirements": all requirements or conditions for licence
- "app_guidance": all application or registration processes
- "other": other information
- "url": source page URL

STRICT RULES:
1. Only use the official licence names listed below.
2. If a section explicitly says that a licence is not required, set "licence": "No licence required" and include a short reason.
3. Do NOT invent or guess licence names (e.g., "Vending Machine Licence", "Pet Cafe Licence", "Food Catering Permit"). 
4. Please note that specific types of Food Shops, such as Pet Cafes, Mobile Food Wagons, Vending Machines, Private Markets, Herbal Tea and Mini Restaurants need 




 licence and have specific requirements, not Supermarket Licence.
5. If nothing relevant appears, return an empty array [].

VALID LICENCE NAMES:

-- Singapore Food Agency (SFA) --
"Licence for Import/Export/Transhipment of Meat and Fish Products",
"Licence for Import/Transhipment of Fresh Fruits and Vegetables",
"Licence to Import Poultry",
"Licence to Import Sheep & Goats",
"Licence to Import Table Eggs",
"Licence to Import/Export/Tranship Food Animals, Birds, Eggs and Biologics",
"Registration to Import Animal Feed",
"Registration to Import Feed for Food-Producing Animals",
"Registration to Import Processed Food Products and Food Appliances",
"Registration to Import Live Frogs for Human Consumption",
"Rice Licence",
"Food Shop Licence",
"Food Stall Licence",
"Supermarket Licence",
"Permit for Temporary Fair",
"Temporary Fair Stall Licence",
"Licence to Manufacture Animal Feed and Process of Animal Feed for Food-Producing Animals",
"Licence to Operate a Food Processing Establishment",
"Licence to Operate a Coldstore",
"Licence to Operate a Slaughterhouse",
"Export Health Certificate",
"Health Certificate for Export of Live Foodfish for Breeding",
"Free Sale Certificate (Food)",
"Free Sale Certificate (Animal Feed) for Food-Producing Animals",
"Veterinary Certificate for Food-Producing Animals",
"Submission Form for Food Safety Management System (FSMS)",

-- Other Agencies --
"Liquor Licence (Singapore Police Force)",
"Entertainment Licence (Singapore Police Force)",
"Hawker Stall Licence (National Environment Agency)",
"Vehicle Registration for Goods Vehicle (Land Transport Authority)",
"Halal Certification (Majlis Ugama Islam Singapura - MUIS) - Eating Establishment Scheme (Category 1)",
"Halal Certification (Majlis Ugama Islam Singapura - MUIS) - Product / Whole Plant Scheme",
"Halal Certification (Majlis Ugama Islam Singapura - MUIS) - Poultry Scheme",
"Halal Certification (Majlis Ugama Islam Singapura - MUIS) - Storage Facility Scheme",
"Halal Certification (Majlis Ugama Islam Singapura - MUIS) - Food Preparation Area Scheme",
"Halal Certification (Majlis Ugama Islam Singapura - MUIS) - Endorsement Scheme",
"Tobacco Retail Licence (Health Sciences Authority)"

TEXT EXTRACTED FROM HTML:
{text}

URL:
{url}
"""

    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
        temperature=0
    )
    text = response.choices[0].message.content
    return text
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
structured_data = []
for page in all_pages:
    json_text = parse_text_with_llm(page['text'], page['url'])
    try:
        data = json.loads(json_text)
        structured_data.append(data)
        print(f"✅ Successfully parsed: {page['url']}")
    except json.JSONDecodeError:
        print(f"❌ Error parsing JSON for {page['url']}")
        print(json_text)
# Out:
# ✅ Successfully parsed: https://file.go.gov.sg/hcc-eec1.pdf
# ✅ Successfully parsed: https://file.go.gov.sg/hcc-pwp.pdf
# ✅ Successfully parsed: https://file.go.gov.sg/hcc-pa.pdf
# ✅ Successfully parsed: https://file.go.gov.sg/hec-en.pdf
# ✅ Successfully parsed: https://file.go.gov.sg/hcc-sf.pdf
# ✅ Successfully parsed: https://file.go.gov.sg/hcc-fpa.pdf
# ✅ Successfully parsed: https://www.sfa.gov.sg/food-import-export/commercial-imports/what-you-need-to-know-for-import-of-animal-feed
# ✅ Successfully parsed: https://www.sfa.gov.sg/commercial-exports/what-you-need-to-know-for-export-tranship-of-animal-feed
# ✅ Successfully parsed: https://www.gobusiness.gov.sg/browse-all-licences/singapore-food-agency-(sfa)/licence-for-import-export-transhipment-of-meat-and-fish-products
# ✅ Successfully parsed: https://www.gobusiness.gov.sg/browse-all-licences/singapore-food-agency-(sfa)/licence-for-import-transhipment-of-fresh-fruits-and-vegetables
# ✅ Successfully parsed: https://www.gobusiness.gov.sg/browse-all-licences/singapore-food-agency-(sfa)/licence-to-import-poultry
# ✅ Successfully parsed: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/Licence-to-Import-Sheep-&-Goats
# ✅ Successfully parsed: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/Licence-to-Import-Table-Eggs
# ✅ Successfully parsed: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/licence-to-import-export-tranship-food-animals--birds--eggs-and-biologics
# ✅ Successfully parsed: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/Registration-to-Import-Animal-Feed
# ✅ Successfully parsed: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/Registration-to-Import-Feed-for-Food-Producing-Animals
# ✅ Successfully parsed: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/Registration-to-Import-Processed-Food-Products-and-Food-Appliances
# ✅ Successfully parsed: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/Registration-to-Import-Live-Frogs-for-Human-Consumption
# ✅ Successfully parsed: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/Rice-Licence
# ✅ Successfully parsed: https://www.sfa.gov.sg/food-retail/licence-permit/requirements-for-licence-permit-for-food-retail
# ✅ Successfully parsed: https://www.sfa.gov.sg/food-retail/businesses-that-currently-do-not-need-licence-permit/online-food-businesses/types-of-online-food-businesses
# ✅ Successfully parsed: https://www.sfa.gov.sg/food-retail/businesses-that-currently-do-not-need-licence-permit/home-based-food-businesses/about-hdb-ura-home-based-business-scheme
# ✅ Successfully parsed: https://www.sfa.gov.sg/food-retail/businesses-that-currently-do-not-need-licence-permit/food-delivery-businesses/requirements-for-food-delivery-businesses
# ✅ Successfully parsed: https://www.sfa.gov.sg/food-retail/businesses-that-currently-do-not-need-licence-permit/group-buy-activities/guidelines-for-group-buy-organisers
# ✅ Successfully parsed: https://www.gobusiness.gov.sg/browse-all-licences/singapore-food-agency-(sfa)/food-shop-licence
# ✅ Successfully parsed: https://www.gobusiness.gov.sg/browse-all-licences/singapore-food-agency-(sfa)/food-stall-licence
# ✅ Successfully parsed: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/Supermarket-Licence
# ✅ Successfully parsed: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/Permit-for-Temporary-Fair
# ✅ Successfully parsed: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/Temporary-Fair-Stall-Licence
# ✅ Successfully parsed: https://www.sfa.gov.sg/food-manufacturing-storage/licence-registration/businesses-that-need-licence-registration-for-food-manufacturing-storage
# ✅ Successfully parsed: https://www.sfa.gov.sg/food-manufacturing-storage/licence-registration/application-process-fees-for-licence-to-manufacture-and-process-animal-feed
# ✅ Successfully parsed: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/Licence-to-Manufacture-Animal-Feed-and-Process-of-Animal-Feed-for-Food-Producing-Animals
# ✅ Successfully parsed: https://www.sfa.gov.sg/farming/licence-registration/businesses-that-need-licence-registration-for-farming
# ✅ Successfully parsed: https://www.sfa.gov.sg/farming/pesticides/requirements-for-pesticide-usage-in-farms
# ✅ Successfully parsed: https://www.sfa.gov.sg/wholesale-markets-fishery-ports/licence-registration/businesses-that-need-licence-registration-for-fishing-vessel-gear-personnel
# ✅ Successfully parsed: https://www.gobusiness.gov.sg/browse-all-licences/singapore-food-agency-(sfa)/health-certificate-for-export-of-live-foodfish-for-breeding
# ✅ Successfully parsed: https://www.gobusiness.gov.sg/browse-all-licences/singapore-food-agency-(sfa)/export-health-certificate
# ✅ Successfully parsed: https://www.gobusiness.gov.sg/browse-all-licences/singapore-food-agency-(sfa)/free-sale-certificate-(food)
# ✅ Successfully parsed: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/Free-Sale-Certificate-(Animal-Feed)-for-Food-Producing-Animals
# ✅ Successfully parsed: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/Veterinary-Certificate-for-Food-Producing-Animals
# ✅ Successfully parsed: https://www.gobusiness.gov.sg/browse-all-licences/Singapore-Food-Agency-(SFA)/Submission-Form-for-Food-Safety-Management-System
# ✅ Successfully parsed: https://www.sfa.gov.sg/regulatory-standards-frameworks-guidelines/food-safety-management/understanding-food-safety-management-system-fsms
# ✅ Successfully parsed: https://www.sfa.gov.sg/faqs#food-retail-general
# ✅ Successfully parsed: https://www.police.gov.sg/E-Services/Apply-for-Liquor-Licence
# ✅ Successfully parsed: https://onemotoring.lta.gov.sg/content/onemotoring/home/buying/vehicle-types-and-registrations/commercial-vehicle/goods-vehicle-and-engineering-plant.html
# ✅ Successfully parsed: https://www.nea.gov.sg/our-services/hawker-management/becoming-a-hawker
# ✅ Successfully parsed: https://www.muis.gov.sg/halal/for-business/scheme-types---eligibility-criteria/
# ✅ Successfully parsed: https://www.hsa.gov.sg/tobacco-regulation/licences/retail/apply
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Save raw data

# %%
with open("data/alllicenceinfo_parsed.json", "w", encoding="utf-8") as f:
    json.dump(structured_data, f, indent=2, ensure_ascii=False)

print("Raw Data JSON saved")
# Out:
# Raw Data JSON saved
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Adding and Parsing content of additional URLs

# %%
# # New URLs only
# new_urls = [
#     "https://www.police.gov.sg/Business-E-Services/Apply-for-Public-Entertainment-Licence"
# ]

# # File path
# output_file = "data/alllicenceinfo_parsed.json"

# # Step 0: Load existing data if file exists
# if os.path.exists(output_file):
#     with open(output_file, "r", encoding="utf-8") as f:
#         structured_data = json.load(f)
# else:
#     structured_data = []

# # Step 1: Fetch & clean HTML for new URLs
# html_pages = []
# for url in new_urls:
#     resp = requests.get(url)
#     soup = BeautifulSoup(resp.text, "html.parser")

#     # Remove noise
#     for tag in soup(["script", "style", "noscript"]):
#         tag.decompose()

#     text_content = soup.get_text(separator="\n", strip=True)
#     html_pages.append({"url": url, "text": text_content})


# # Step 2: LLM parsing function
# def parse_text_with_llm(text, url):
#     prompt = f"""
# You are a careful information extraction assistant specialising in Singapore Food Agency (SFA) and other food-related regulatory licences. 
# Extract information only if it clearly relates to official licences, permits, registrations, or certificates — or if the text explicitly says that no licence is required.

# Return ONLY a valid JSON array of objects, no markdown, no comments, no explanations. 
# Each object must have:
# - "title": short descriptive title (from the text if possible)
# - "description": relevant text excerpt including URLs if found
# - "licence": 
#     - one exact matching licence name (from the official list below), OR
#     - "No licence required" if the text states that no licence is needed
# - "reason": short explanation (e.g., “Prepacked beverages are exempt from licensing”)
# - "subsection": subsection heading if available, else null
# - "url": source page URL

# STRICT RULES:
# 1. Only use the official licence names listed below.
# 2. If a section explicitly says that a licence is not required, set "licence": "No licence required" and include a short reason.
# 3. Do NOT invent or guess licence names (e.g., “Vending Machine Licence”, “Café Licence”, “Food Catering Permit”).
# 4. If nothing relevant appears, return an empty array [].

# VALID LICENCE NAMES:

# -- Singapore Food Agency (SFA) --
# "Licence for Import/Export/Transhipment of Meat and Fish Products",
# "Licence for Import/Transhipment of Fresh Fruits and Vegetables",
# "Licence to Import Poultry",
# "Licence to Import Sheep & Goats",
# "Licence to Import Table Eggs",
# "Licence to Import/Export/Tranship Food Animals, Birds, Eggs and Biologics",
# "Registration to Import Animal Feed",
# "Registration to Import Feed for Food-Producing Animals",
# "Registration to Import Processed Food Products and Food Appliances",
# "Registration to Import Live Frogs for Human Consumption",
# "Rice Licence",
# "Food Shop Licence",
# "Food Stall Licence",
# "Supermarket Licence",
# "Permit for Temporary Fair",
# "Temporary Fair Stall Licence",
# "Licence to Manufacture Animal Feed and Process of Animal Feed for Food-Producing Animals",
# "Licence to Operate a Food Processing Establishment",
# "Licence to Operate a Coldstore",
# "Licence to Operate a Slaughterhouse",
# "Export Health Certificate",
# "Health Certificate for Export of Live Foodfish for Breeding",
# "Free Sale Certificate (Food)",
# "Free Sale Certificate (Animal Feed) for Food-Producing Animals",
# "Veterinary Certificate for Food-Producing Animals",
# "Submission Form for Food Safety Management System (FSMS)",

# -- Other Agencies --
# "Liquor Licence (Singapore Police Force)",
# "https://www.police.gov.sg/Business-E-Services/Apply-for-Public-Entertainment-Licence",
# "Hawker Stall Licence (National Environment Agency)",
# "Vehicle Registration for Goods Vehicle (Land Transport Authority)",
# "Halal Certification (Majlis Ugama Islam Singapura - MUIS)",
# "Tobacco Retail Licence (Health Sciences Authority)"

# TEXT EXTRACTED FROM HTML:
# {text}

# URL:
# {url}
# """

#     response = client.chat.completions.create(
#         model="gpt-4o-mini",
#         messages=[{"role": "user", "content": prompt}],
#         temperature=0
#     )
#     return response.choices[0].message.content


# # Step 3: Process only new URLs and append results
# for page in html_pages:
#     json_text = parse_text_with_llm(page['text'], page['url'])
#     try:
#         data = json.loads(json_text)
#         structured_data.append(data)
#         print(f"✅ Successfully parsed: {page['url']}")
#     except json.JSONDecodeError:
#         print(f"❌ Error parsing JSON for {page['url']}")
#         print(json_text)


# # Step 4: Save updated data back
# with open(output_file, "w", encoding="utf-8") as f:
#     json.dump(structured_data, f, indent=2, ensure_ascii=False)

# print(f"📂 Updated JSON saved at {output_file}")
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Preview final JSON

# %%
with open("data/alllicenceinfo_parsed.json", "r", encoding="utf-8") as f:
    preview_data = json.load(f)

# Show only first X entries
preview_count = 3
preview_subset = preview_data[:preview_count]

print(json.dumps(preview_subset, indent=2, ensure_ascii=False))
# Out:
# [
#   [
#     {
#       "title": "MUIS Halal Certification Conditions HCC EEC1 (Version 4.0)",
#       "subsection": "Eating Establishment Scheme (Category 1)",
#       "licence": "Halal Certification (Majlis Ugama Islam Singapura - MUIS) - Eating Establishment Scheme (Category 1)",
#       "description": "This document is provided for the application for Halal Certification by the Majlis Ugama Islam Singapura with effect from 1 October 2025. The Eating Establishment scheme (Category 1) in this document shall be applicable to the operation of the following types of retail food establishments in Singapore: Hawker Stalls, Snack bars / Bakeries, School Canteen Stalls, Short-term Stalls.",
#       "reason_for_licence": "Companies/establishments applying for a Halal certification from MUIS must comply with the MUIS Halal Certification Conditions.",
#       "requirements": "The applicant shall read, understand and agree to adhere to the MUIS Halal Certification Conditions upon submission of the application. The applicant shall ensure that there is no cross-mixing of Halal and non-Halal food and ingredients. The applicant shall engage at least 1 permanent Muslim personnel.",
#       "app_guidance": "The processing of application shall commence within 14 working days from the date of payment for New (normal) processing application. The applicant shall access the application portal regularly for information on application status and Request For Action notices.",
#       "other": "MUIS reserves the right to suspend or revoke the Halal certificate with immediate effect upon acknowledgement/written notice to the certificate holder if any conditions are breached.",
#       "url": "https://file.go.gov.sg/hcc-eec1.pdf"
#     }
#   ],
#   [
#     {
#       "title": "MUIS Halal Certification Conditions HCC PWP (Version 4.0)",
#       "subsection": "Product / Whole Plant Scheme",
#       "licence": "Halal Certification (Majlis Ugama Islam Singapura - MUIS) - Product / Whole Plant Scheme",
#       "description": "This document is provided for the application for Halal Certification by the Majlis Ugama Islam Singapura with effect from 01 October 2025.",
#       "reason_for_licence": "Companies applying for Halal certification must comply with MUIS Halal Certification Conditions.",
#       "requirements": "The applicant shall read, understand and agree to adhere to the MUIS Halal Certification Conditions upon submission of the application.",
#       "app_guidance": "The processing of application shall commence within 14 working days from the date of payment for New (normal) application.",
#       "other": "MUIS may conduct unannounced periodic inspections as and when necessary following the award of the Halal certificate.",
#       "url": "https://file.go.gov.sg/hcc-pwp.pdf"
#     }
#   ],
#   [
#     {
#       "title": "MUIS Halal Certification Conditions - Poultry Scheme",
#       "subsection": "Poultry Scheme",
#       "licence": "Halal Certification (Majlis Ugama Islam Singapura - MUIS) - Poultry Scheme",
#       "description": "The Poultry scheme shall be applicable to selected fresh whole poultry which is slaughtered in Singapore. The scope of certification shall include: (a) poultry feed; (b) transporting, receiving, stunning, slaughtering, scalding, de-feathering, evisceration, labelling, sorting and storage of poultry.",
#       "reason_for_licence": "The applicant must comply with MUIS Halal Certification Conditions to obtain a Halal certificate for poultry.",
#       "requirements": "The applicant shall ensure and provide documentation to prove the poultry are grain/corn fed and not injected with any hormones while breeding. The applicant shall also apply for additional schemes if processing, packing, or selling cut poultry pieces.",
#       "app_guidance": "The processing of application shall commence within 14 working days from the date of payment for New (normal) processing application. The applicant shall access the application portal regularly for information on application status.",
#       "other": "The Halal certificate is valid for the period stipulated on the certificate and shall not be displayed outside the certified premises.",
#       "url": "https://file.go.gov.sg/hcc-pa.pdf"
#     }
#   ]
# ]
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Chunking and Vector Indexing

# %%
import json
from langchain_experimental.text_splitter import SemanticChunker
from langchain_openai.embeddings import OpenAIEmbeddings
from langchain.docstore.document import Document
import faiss
import numpy as np
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# 1. Load and flatten JSON

# %%
with open("data/alllicenceinfo_parsed.json", "r", encoding="utf-8") as f:
    licence_data = json.load(f)

# Flatten nested lists
flat_licence_data = []
for item in licence_data:
    if isinstance(item, list):
        flat_licence_data.extend(item)
    else:
        flat_licence_data.append(item)
licence_data = flat_licence_data
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# 2. Create Chunks

# %%
all_chunks = []
all_metadata = []

for i, item in enumerate(licence_data):
    title = str(item.get("title", ""))
    url = str(item.get("url", ""))
    description = str(item.get("description", ""))
    reason = str(item.get("reason_for_licence", ""))
    
    reqs = item.get("requirements", [])
    if isinstance(reqs, list):
        requirements = " ".join([str(r) for r in reqs])
    else:
        requirements = str(reqs)
    
    app_guidance = str(item.get("app_guidance", ""))
    other = str(item.get("other", ""))
    licence_name = str(item.get("licence", title))

    # Include URL in the chunk text
    chunk_text = "\n".join(filter(None, [description, reason, requirements, app_guidance, other, f"URL: {url}" if url else ""]))
    all_chunks.append(chunk_text)

    safe_title = "".join(c if c.isalnum() else "_" for c in title) or f"doc_{i}"
    chunk_id = f"{safe_title}_{i}"

    all_metadata.append({
        "chunk_id": chunk_id,
        "title": title,
        "licence_name": licence_name,
        "url": url,
        "original_index": i
    })

print(f"Total chunks created: {len(all_chunks)}")
print("Example chunk:\n", all_chunks[0])
# Out:
# Total chunks created: 58
# Example chunk:
#  This document is provided for the application for Halal Certification by the Majlis Ugama Islam Singapura with effect from 1 October 2025. The Eating Establishment scheme (Category 1) in this document shall be applicable to the operation of the following types of retail food establishments in Singapore: Hawker Stalls, Snack bars / Bakeries, School Canteen Stalls, Short-term Stalls.
# Companies/establishments applying for a Halal certification from MUIS must comply with the MUIS Halal Certification Conditions.
# The applicant shall read, understand and agree to adhere to the MUIS Halal Certification Conditions upon submission of the application. The applicant shall ensure that there is no cross-mixing of Halal and non-Halal food and ingredients. The applicant shall engage at least 1 permanent Muslim personnel.
# The processing of application shall commence within 14 working days from the date of payment for New (normal) processing application. The applicant shall access the application portal regularly for information on application status and Request For Action notices.
# MUIS reserves the right to suspend or revoke the Halal certificate with immediate effect upon acknowledgement/written notice to the certificate holder if any conditions are breached.
# URL: https://file.go.gov.sg/hcc-eec1.pdf
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# 3. Generate embeddings for all chunks

# %%
embeddings_model = OpenAIEmbeddings()
chunk_embeddings = embeddings_model.embed_documents(all_chunks)
chunk_embeddings = np.array(chunk_embeddings).astype("float16")
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# 6. Create FAISS vector store

# %%
dimension = chunk_embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(chunk_embeddings)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Stack all embeddings into a single 2D array (num_chunks, 1536)
X = np.vstack([emb.astype(np.float16).reshape(1, -1) for emb in chunk_embeddings])
X = np.ascontiguousarray(X, dtype=np.float16)

print("Shape:", X.shape)
print("Dtype:", X.dtype)
print("C_CONTIGUOUS:", X.flags['C_CONTIGUOUS'])

# Create FAISS index
dimension = X.shape[1]
index = faiss.IndexFlatL2(dimension)

# Add embeddings
index.add(X)
print(f"FAISS index created with {index.ntotal} vectors")
# Out:
# Shape: (58, 1536)
# Dtype: float16
# C_CONTIGUOUS: True
# FAISS index created with 58 vectors
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Keep track of metadata using chunk_id as key
metadata_dict = {meta["chunk_id"]: meta for meta in all_metadata}

# Example: inspect first 3 entries
for k, v in list(metadata_dict.items())[:3]:
    print(f"Chunk ID: {k}")
    print("Metadata:", v)
    print("---")
# Out:
# Chunk ID: MUIS_Halal_Certification_Conditions_HCC_EEC1__Version_4_0__0
# Metadata: {'chunk_id': 'MUIS_Halal_Certification_Conditions_HCC_EEC1__Version_4_0__0', 'title': 'MUIS Halal Certification Conditions HCC EEC1 (Version 4.0)', 'licence_name': 'Halal Certification (Majlis Ugama Islam Singapura - MUIS) - Eating Establishment Scheme (Category 1)', 'url': 'https://file.go.gov.sg/hcc-eec1.pdf', 'original_index': 0}
# ---
# Chunk ID: MUIS_Halal_Certification_Conditions_HCC_PWP__Version_4_0__1
# Metadata: {'chunk_id': 'MUIS_Halal_Certification_Conditions_HCC_PWP__Version_4_0__1', 'title': 'MUIS Halal Certification Conditions HCC PWP (Version 4.0)', 'licence_name': 'Halal Certification (Majlis Ugama Islam Singapura - MUIS) - Product / Whole Plant Scheme', 'url': 'https://file.go.gov.sg/hcc-pwp.pdf', 'original_index': 1}
# ---
# Chunk ID: MUIS_Halal_Certification_Conditions___Poultry_Scheme_2
# Metadata: {'chunk_id': 'MUIS_Halal_Certification_Conditions___Poultry_Scheme_2', 'title': 'MUIS Halal Certification Conditions - Poultry Scheme', 'licence_name': 'Halal Certification (Majlis Ugama Islam Singapura - MUIS) - Poultry Scheme', 'url': 'https://file.go.gov.sg/hcc-pa.pdf', 'original_index': 2}
# ---
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Save raw chunks, metadata and embeddings

# %%
# Save raw chunks
with open("data/all_chunks.json", "w", encoding="utf-8") as f:
    json.dump(all_chunks, f, ensure_ascii=False, indent=2)

# Save metadata
with open("data/all_metadata.json", "w", encoding="utf-8") as f:
    json.dump(all_metadata, f, ensure_ascii=False, indent=2)

# Save embeddings as a contiguous float16 array
X = np.array(chunk_embeddings, dtype=np.float16)          # convert all at once
X = np.ascontiguousarray(X)                               # make contiguous in memory
np.save("data/chunk_embeddings.npy", X)

# Save FAISS index
dimension = X.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(X)                                              # add float16 vectors
faiss.write_index(index, "data/faiss_index.index")

print("Chunks, metadata, embeddings, and FAISS index saved successfully!")
# Out:
# Chunks, metadata, embeddings, and FAISS index saved successfully!
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Sample query

# %%
# -------------------------------
# 1️⃣ Define the user query
# -------------------------------
business_type = "Vending Machine"
additional_details = "selling raw seafood"

# Combine business type + details into query text for embeddings
query_text = f"Business type: {business_type}. Details: {additional_details}"

# -------------------------------
# 2️⃣ Embed the query
# -------------------------------
query_vector = np.array(embeddings_model.embed_query(query_text), dtype=np.float16)

# -------------------------------
# 3️⃣ Compute similarity to ALL chunks
# -------------------------------
def cosine_similarity(a, b):
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

similarities = [cosine_similarity(query_vector, emb) for emb in X]

# -------------------------------
# 4️⃣ Rank chunks by similarity
# -------------------------------
top_n = 12  # get more candidates initially
sorted_indices = np.argsort(similarities)[::-1]
top_indices = sorted_indices[:top_n]

# -------------------------------
# 4a️⃣ Filter by business type keywords
# -------------------------------
business_keywords = ["vending machine", "food shop", "retail outlet"]
filtered_indices = [
    i for i in top_indices
    if any(kw.lower() in all_chunks[i].lower() for kw in business_keywords)
]

filtered_chunks = [all_chunks[i] for i in filtered_indices]
filtered_metadata = [all_metadata[i] for i in filtered_indices]

print(f"Selected {len(filtered_chunks)} chunks after business-type filtering.\n")

# Debug: show scores and metadata
for idx in filtered_indices:
    meta = all_metadata[idx]
    print(f"Score: {similarities[idx]:.3f}")
    print("Title:", meta["title"])
    print("Licence:", meta.get("licence_name", meta["title"]))
    print("Preview:", all_chunks[idx][:200], "\n---")

# -------------------------------
# 5️⃣ Combine chunks into prompt
# -------------------------------
combined_context = "\n\n".join(filtered_chunks)

prompt = f"""
You are a knowledgeable assistant for Singapore food business regulations.

Given the following government-sourced information:

{combined_context}

The user wants to open a business with these details:
Business type: {business_type}
Product sold: {additional_details}

Instructions for you:
- Only list licences, permits, or approvals that are specifically relevant to this type of business and product.
- Ignore general licences that cover unrelated food types or retail formats.
- Provide plain-language explanation of why each licence is required.
- Include step-by-step guidance or application URLs if available.
"""

# -------------------------------
# 6️⃣ Ask LLM to summarise
# -------------------------------
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": prompt}],
    temperature=0
)

summary = response.choices[0].message.content
print("\n--- Summary for User ---\n")
print(summary)
# Out:
# Selected 2 chunks after business-type filtering.
#
# Score: 0.777
# Title: Requirements for Food Shop Licences
# Licence: Food Shop Licence
# Preview: Food Shops include bakeries, restaurants, food vending machines, canteens, coffee shops, eating houses, food courts, standalone kiosks, takeaway food carts, and private canteens/markets.
# Food Shops mu
# ---
# Score: 0.765
# Title: Food Shop Licence
# Licence: Food Shop Licence
# Preview: For the operation of a food shop where there is retail sale of food and/or beverage. You will need to apply for a Food Shop Licence if you intend to operate a retail food outlet where food and/or drin
# ---
#
# --- Summary for User ---
#
# For your vending machine business selling raw seafood in Singapore, you will need to obtain the following specific licences and approvals:
#
# ### 1. Food Shop Licence
# **Why it's required:** The Food Shop Licence is necessary for any retail outlet that sells food and/or beverages. Since you are selling raw seafood through a vending machine, this licence ensures that your operation meets cleanliness and food safety standards, which is crucial for preventing food-borne diseases.
#
# **Steps to apply:**
# 1. **Obtain In-Principle Approval:** Before you start, you need to get initial approval from the relevant authorities.
# 2. **Commence Renovation & Set-up:** Once you have the approval, you can begin setting up your vending machine and any necessary infrastructure.
# 3. **Request for Inspection:** After setting up, you will need to request an inspection to ensure compliance with health and safety regulations.
# 4. **Complete Payment for Licence:** Pay the licence fee of S$195.00 to finalize your application.
#
# **Validity:** The licence is valid for 1 year.
#
# **Application URL:** [Food Shop Licence Application](https://www.gobusiness.gov.sg/browse-all-licences/singapore-food-agency-(sfa)/food-shop-licence)
#
# ### 2. Environmental Sanitation Programme (ESP)
# **Why it's required:** If your vending machine operation requires it, you may need to implement an Environmental Sanitation Regime (ESR) and submit an ESP. This is particularly important for businesses dealing with raw seafood, as it helps ensure that your vending machine is maintained in a sanitary condition to prevent contamination.
#
# **Steps to implement:**
# - Develop an Environmental Sanitation Programme that outlines how you will maintain cleanliness and hygiene in your vending machine.
# - Submit the ESP to the National Environment Agency (NEA) within 1 month of your licence application if required.
#
# **Additional Information:** You may need to provide hand sanitizers and disposable gloves if your vending machine allows for self-service.
#
# ### Summary
# To operate your vending machine selling raw seafood, you primarily need the Food Shop Licence to ensure compliance with food safety regulations. Additionally, be prepared to implement an Environmental Sanitation Programme if required. Make sure to follow the outlined steps for a smooth application process.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
